# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import TensorDataset # 텐서데이터셋
from torch.utils.data import DataLoader # 데이터로더

x_train  =  torch.FloatTensor([[73,  80,  75], 
                               [93,  88,  93], 
                               [89,  91,  90], 
                               [96,  98,  100],   
                               [73,  66,  70]])  
y_train  =  torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])


dataset = TensorDataset(x_train, y_train)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)
model = nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5) 

nb_epochs = 20
for epoch in range(nb_epochs + 1):
    for batch_idx, samples in enumerate(dataloader):
        # print(batch_idx)
        # print(samples)
        x_train, y_train = samples
        # H(x) 계산
        prediction = model(x_train)

        # cost 계산
        cost = F.mse_loss(prediction, y_train)

        # cost로 H(x) 계산
        optimizer.zero_grad()
        cost.backward()
        optimizer.step()

        print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
# Out:
# Epoch    0/20 Batch 1/3 Cost: 13733.040039
# Epoch    0/20 Batch 2/3 Cost: 9919.441406
# Epoch    0/20 Batch 3/3 Cost: 2511.637695
# Epoch    1/20 Batch 1/3 Cost: 337.573883
# Epoch    1/20 Batch 2/3 Cost: 259.616760
# Epoch    1/20 Batch 3/3 Cost: 20.213762
# Epoch    2/20 Batch 1/3 Cost: 2.269041
# Epoch    2/20 Batch 2/3 Cost: 32.336998
# Epoch    2/20 Batch 3/3 Cost: 18.946589
# Epoch    3/20 Batch 1/3 Cost: 12.611603
# Epoch    3/20 Batch 2/3 Cost: 17.382507
# Epoch    3/20 Batch 3/3 Cost: 6.383765
# Epoch    4/20 Batch 1/3 Cost: 18.330069
# Epoch    4/20 Batch 2/3 Cost: 7.698470
# Epoch    4/20 Batch 3/3 Cost: 1.519842
# Epoch    5/20 Batch 1/3 Cost: 21.336020
# Epoch    5/20 Batch 2/3 Cost: 14.641094
# Epoch    5/20 Batch 3/3 Cost: 0.524793
# Epoch    6/20 Batch 1/3 Cost: 23.397800
# Epoch    6/20 Batch 2/3 Cost: 13.471424
# Epoch    6/20 Batch 3/3 Cost: 0.408350
# Epoch    7/20 Batch 1/3 Cost: 8.478343
# Epoch    7/20 Batch 2/3 Cost: 16.768883
# Epoch    7/20 Batch 3/3 Cost: 1.940421
# Epoch    8/20 Batch 1/3 Cost: 2.435824
# Epoch    8/20 Batch 2/3 Cost: 18.457392
# Epoch    8/20 Batch 3/3 Cost: 10.514946
# Epoch    9/20 Batch 1/3 Cost: 10.774722
# Epoch    9/20 Batch 2/3 Cost: 19.782841
# Epoch    9/20 Batch 3/3 Cost: 13.735633
# Epoch   10/20 Batch 1/3 Cost: 13.789840
# Epoch   10/20 Batch 2/3 Cost: 7.093715
# Epoch   10/20 Batch 3/3 Cost: 10.045986
# Epoch   11/20 Batch 1/3 Cost: 0.904084
# Epoch   11/20 Batch 2/3 Cost: 20.109140
# Epoch   11/20 Batch 3/3 Cost: 12.073441
# Epoch   12/20 Batch 1/3 Cost: 8.654426
# Epoch   12/20 Batch 2/3 Cost: 7.495914
# Epoch   12/20 Batch 3/3 Cost: 25.832624
# Epoch   13/20 Batch 1/3 Cost: 13.017279
# Epoch   13/20 Batch 2/3 Cost: 14.965055
# Epoch   13/20 Batch 3/3 Cost: 20.884270
# Epoch   14/20 Batch 1/3 Cost: 3.853891
# Epoch   14/20 Batch 2/3 Cost: 28.970562
# Epoch   14/20 Batch 3/3 Cost: 3.809573
# Epoch   15/20 Batch 1/3 Cost: 16.182457
# Epoch   15/20 Batch 2/3 Cost: 5.343161
# Epoch   15/20 Batch 3/3 Cost: 13.780572
# Epoch   16/20 Batch 1/3 Cost: 14.613514
# Epoch   16/20 Batch 2/3 Cost: 4.192825
# Epoch   16/20 Batch 3/3 Cost: 13.256040
# Epoch   17/20 Batch 1/3 Cost: 17.821503
# Epoch   17/20 Batch 2/3 Cost: 7.442969
# Epoch   17/20 Batch 3/3 Cost: 1.552826
# Epoch   18/20 Batch 1/3 Cost: 20.841105
# Epoch   18/20 Batch 2/3 Cost: 9.569272
# Epoch   18/20 Batch 3/3 Cost: 6.426630
# Epoch   19/20 Batch 1/3 Cost: 19.420454
# Epoch   19/20 Batch 2/3 Cost: 7.712213
# Epoch   19/20 Batch 3/3 Cost: 0.993054
# Epoch   20/20 Batch 1/3 Cost: 1.786944
# Epoch   20/20 Batch 2/3 Cost: 9.644768
# Epoch   20/20 Batch 3/3 Cost: 29.695980

# %% [markdown]
# 그런데 torch.utils.data.Dataset을 상속받아 직접 커스텀 데이터셋(Custom Dataset)을 만드는 경우도 있습니다. torch.utils.data.Dataset은 파이토치에서 데이터셋을 제공하는 추상 클래스입니다. Dataset을 상속받아 다음 메소드들을 오버라이드 하여 커스텀 데이터셋을 만들어보겠습니다.
#
# 커스텀 데이터셋을 만들 때, 일단 가장 기본적인 뼈대는 아래와 같습니다. 여기서 필요한 기본적인 define은 3개입니다.

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
# Dataset 상속
class CustomDataset(Dataset): 
    def __init__(self):
        self.x_data = [[73, 80, 75],
                       [93, 88, 93],
                       [89, 91, 90],
                       [96, 98, 100],
                       [73, 66, 70]]
        self.y_data = [[152], [185], [180], [196], [142]]

    # 총 데이터의 개수를 리턴
    def __len__(self): 
        return len(self.x_data)

    # 인덱스를 입력받아 그에 맵핑되는 입출력 데이터를 파이토치의 Tensor 형태로 리턴
    def __getitem__(self, idx): 
        x = torch.FloatTensor(self.x_data[idx])
        y = torch.FloatTensor(self.y_data[idx])
        return x, y

# %%
dataset = CustomDataset()
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
model = torch.nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):
    for batch_idx, samples in enumerate(dataloader):
        # print(batch_idx)
        # print(samples)
        x_train, y_train = samples
        # H(x) 계산
        prediction = model(x_train)

        # cost 계산
        cost = F.mse_loss(prediction, y_train)

        # cost로 H(x) 계산
        optimizer.zero_grad()
        cost.backward()
        optimizer.step()

        print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
            epoch, nb_epochs, batch_idx+1, len(dataloader),
            cost.item()
            ))
# Out:
# Epoch    0/20 Batch 1/3 Cost: 82313.851562
# Epoch    0/20 Batch 2/3 Cost: 14804.573242
# Epoch    0/20 Batch 3/3 Cost: 3770.150391
# Epoch    1/20 Batch 1/3 Cost: 2357.720703
# Epoch    1/20 Batch 2/3 Cost: 875.120911
# Epoch    1/20 Batch 3/3 Cost: 210.651993
# Epoch    2/20 Batch 1/3 Cost: 93.159332
# Epoch    2/20 Batch 2/3 Cost: 27.276926
# Epoch    2/20 Batch 3/3 Cost: 0.393013
# Epoch    3/20 Batch 1/3 Cost: 0.721254
# Epoch    3/20 Batch 2/3 Cost: 13.352104
# Epoch    3/20 Batch 3/3 Cost: 12.394835
# Epoch    4/20 Batch 1/3 Cost: 4.056162
# Epoch    4/20 Batch 2/3 Cost: 6.100291
# Epoch    4/20 Batch 3/3 Cost: 14.676980
# Epoch    5/20 Batch 1/3 Cost: 8.788025
# Epoch    5/20 Batch 2/3 Cost: 3.827166
# Epoch    5/20 Batch 3/3 Cost: 4.773014
# Epoch    6/20 Batch 1/3 Cost: 7.683258
# Epoch    6/20 Batch 2/3 Cost: 5.986654
# Epoch    6/20 Batch 3/3 Cost: 2.297767
# Epoch    7/20 Batch 1/3 Cost: 9.423034
# Epoch    7/20 Batch 2/3 Cost: 4.449766
# Epoch    7/20 Batch 3/3 Cost: 2.552018
# Epoch    8/20 Batch 1/3 Cost: 1.857221
# Epoch    8/20 Batch 2/3 Cost: 7.037978
# Epoch    8/20 Batch 3/3 Cost: 13.676544
# Epoch    9/20 Batch 1/3 Cost: 8.361536
# Epoch    9/20 Batch 2/3 Cost: 4.394396
# Epoch    9/20 Batch 3/3 Cost: 11.081292
# Epoch   10/20 Batch 1/3 Cost: 8.208664
# Epoch   10/20 Batch 2/3 Cost: 9.342746
# Epoch   10/20 Batch 3/3 Cost: 11.642178
# Epoch   11/20 Batch 1/3 Cost: 1.497359
# Epoch   11/20 Batch 2/3 Cost: 9.652013
# Epoch   11/20 Batch 3/3 Cost: 8.310520
# Epoch   12/20 Batch 1/3 Cost: 6.313866
# Epoch   12/20 Batch 2/3 Cost: 6.578441
# Epoch   12/20 Batch 3/3 Cost: 4.238750
# Epoch   13/20 Batch 1/3 Cost: 10.737350
# Epoch   13/20 Batch 2/3 Cost: 8.688492
# Epoch   13/20 Batch 3/3 Cost: 1.185898
# Epoch   14/20 Batch 1/3 Cost: 5.658534
# Epoch   14/20 Batch 2/3 Cost: 3.288061
# Epoch   14/20 Batch 3/3 Cost: 17.019527
# Epoch   15/20 Batch 1/3 Cost: 6.322535
# Epoch   15/20 Batch 2/3 Cost: 6.786411
# Epoch   15/20 Batch 3/3 Cost: 8.853022
# Epoch   16/20 Batch 1/3 Cost: 6.199322
# Epoch   16/20 Batch 2/3 Cost: 6.299621
# Epoch   16/20 Batch 3/3 Cost: 4.954659
# Epoch   17/20 Batch 1/3 Cost: 2.403369
# Epoch   17/20 Batch 2/3 Cost: 9.073580
# Epoch   17/20 Batch 3/3 Cost: 8.018067
# Epoch   18/20 Batch 1/3 Cost: 3.946837
# Epoch   18/20 Batch 2/3 Cost: 6.551264
# Epoch   18/20 Batch 3/3 Cost: 8.798896
# Epoch   19/20 Batch 1/3 Cost: 7.595969
# Epoch   19/20 Batch 2/3 Cost: 5.844981
# Epoch   19/20 Batch 3/3 Cost: 2.235147
# Epoch   20/20 Batch 1/3 Cost: 12.311348
# Epoch   20/20 Batch 2/3 Cost: 7.352848
# Epoch   20/20 Batch 3/3 Cost: 1.207631

# %%
# 임의의 입력 [73, 80, 75]를 선언
new_var =  torch.FloatTensor([[73, 80, 75]]) 
# 입력한 값 [73, 80, 75]에 대해서 예측값 y를 리턴받아서 pred_y에 저장
pred_y = model(new_var) 
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[153.6048]], grad_fn=<AddmmBackward>)
